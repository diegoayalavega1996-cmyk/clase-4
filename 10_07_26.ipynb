# %%
lista_numeros = [1,2,3,4,11]
len(lista_numeros)
# Out:
# 5

# %%
lista_numeros.insert(0,10)
print(lista_numeros)
# Out:
# [10, 1, 2, 3, 4, 11]

# %%
lista_numeros.insert(1, 'manzana')
print(lista_numeros)
# Out:
# [10, 'manzana', 1, 2, 3, 4, 11]

# %%
lista_numeros.append(13)
print(lista_numeros)
# Out:
# [10, 'manzana', 1, 2, 3, 4, 11, 13]

# %%
lista_frutas = ['manzana', 'platano']
lista_numeros.append(lista_frutas)
print(lista_numeros)
# Out:
# [10, 'manzana', 1, 2, 3, 4, 11, 13, ['manzana', 'platano']]

# %%
import random
numero_random = random.randint(0,10)
print(numero_random)
# Out:
# 6

# %%
import random
numero_random = []
for _ in range(10):
    numero_random.append(random.randint(0,20))
print(numero_random)
# Out:
# [17, 2, 7, 13, 6, 3, 10, 1, 16, 19]

# %%
sorted(numero_random)
sorted(numero_random, reverse= True)
# Out:
# [19, 17, 16, 13, 10, 7, 6, 3, 2, 1]

# %%
numero_list = [1,2,7,4]
print(numero_list)
numero_list2 = numero_list.sort()
numero_list3 = sorted(numero_list)
print(numero_list3)

print(numero_list)
# Out:
# [1, 2, 7, 4]
# [1, 2, 4, 7]
# [1, 2, 4, 7]

# %%
lista_de_letras = ['a','b','d']
lista_de_letras.pop()
print(lista_de_letras)
# Out:
# ['a', 'b']

# %%
lista_de_letras = ['a','b','d']
lista_de_letras.reverse()
print(lista_de_letras)
# Out:
# ['d', 'b', 'a']

# %%
lista_de_letras = ['a','d','h']
lista_de_letras_2 = ['s','s','b']

lista_de_letras.extend(lista_de_letras_2)
print(lista_de_letras)
# Out:
# ['a', 'd', 'h', 's', 's', 'b']

# %%
lista_de_letras = ['a','d','h']
lista_de_letras_2 = ['s','s','b']

lista_de_letras + lista_de_letras_2
# Out:
# ['a', 'd', 'h', 's', 's', 'b']

# %%
lista_de_letras = ['a','d','h']
lista_de_letras.count('a')
# Out:
# 1

# %%
import random
numero_random = []
for _ in range(10):
    numero_random.append(random.randint(0,5))
print(numero_random)
# Out:
# [1, 4, 4, 5, 4, 5, 5, 0, 2, 1]

# %%
numero_random.count(1)
# Out:
# 2
