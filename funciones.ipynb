# %%
nombre = "diego"
print("cuantas letras tiene mi nombre", len(nombre))
print(len("peru"))
print(nombre.upper())
print(nombre.lower())
#remplaza la letra d por la c
print(nombre.replace("d","c"))
# Out:
# cuantas letras tiene mi nombre 5
# 4
# DIEGO
# diego
# ciego

# %%
apellido = "Ayala       "
print(len(apellido))
apellido_limpio=apellido.strip()
print(len(apellido_limpio))
# Out:
# 12
# 5

# %%
nombres = "Diego Ayala"

nombres_separados = nombres.split(" ")
print(nombres_separados)
# Out:
# ['Diego', 'Ayala']

# %%
nombre = "diego"
print(nombre[0])
ultima_letra= nombre[-1]
print(ultima_letra)
# Out:
# d
# o

# %%
cuenta_total= float(input("ingrese la cuenta total: "))
propina= float(input("ingrese el % de propina"))
monto_propina= cuenta_total * (propina/100)
total_pagar=cuenta_total+monto_propina
print(f"el monto total a pagar es s/ {total_pagar:.2f}")
# Out:
# el monto total a pagar es: 198.00
