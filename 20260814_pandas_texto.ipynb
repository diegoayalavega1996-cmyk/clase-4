# %%
import pandas as pd
df = pd.read_csv(
    "C:/Users/diego/Documents/primer_python/01-python-intro/data/clientes_sucio.csv" 
)

df.head()
# Out:
#                    email        nombre     ciudad   fecha_nac gasto_total  \
# 0    ana.lopez@mail.com      Ana Lopez     MADRID  1985/04/12    1.250,50
# 1    luis.perez@mail.com    luis perez  barcelona  1990-11-03      890,00
# 2       MARTA.R@MAIL.COM    Marta Ruiz   Valencia  12/07/1978    2.100,75
# 3    pedro.diaz@mail.com    Pedro Diaz     madrid  1995-01-30         NaN
# 4    luis.perez@mail.com    luis perez  barcelona  1990-11-03      890,00
#
#   activo       telefono
# 0     Si  +34 600111222
# 1     si    600 222 333
# 2     SI            NaN
# 3     No    600-444-555
# 4     si    600 222 333
